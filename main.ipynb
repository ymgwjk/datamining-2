# %% [markdown]
# # 实验二 频繁模式与关联规则挖掘
#
# 本次实验将完成对Microsoft资讯推荐数据集的频繁模式与关联规则挖掘实验。实验将首先完成数据的预处理，之后完成频繁模式的挖掘，之后对模式进行命名，对挖掘结果进行分析，最后完成可视化的展示

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. 数据预处理
#
# 首先，将数据读出，并处理成事务表的样式。

# %%
with open("data/news.tsv", encoding="utf-8") as f:
    df_news = pd.read_csv(f, delimiter='\t', header=None)

df_news = df_news.set_index(0)
print(df_news[1][:10])

with open("data/behaviors.tsv", encoding="utf-8") as f:
    df_behav = pd.read_csv(f, delimiter='\t', header=None)

print(df_behav[4][:10])

data_list = []
from tqdm import tqdm
import sys
for row in tqdm(df_behav.iterrows(), total=df_behav.shape[0], file=sys.stdout):
    items = row[1][4].split(" ")
    data_row = []
    for item in items:
        name, time = item.split("-")
        if name not in df_news.index:
            continue
        news_find = df_news.loc[name]
        news_type = news_find[1]
        if int(time) == 1:
            data_row.append(news_type)
    if len(data_row) < 2:
        continue
    data_list.append(list(set(data_row)))

for row in data_list:
    print(row)
# Out:
# 0
# N55528    lifestyle
# N18955       health
# N61837         news
# N53526       health
# N38324       health
# N2073        sports
# N11429         news
# N49186      weather
# N2131        health
# N59295         news
# Name: 1, dtype: object
# 0    N28682-0 N48740-0 N31958-1 N34130-0 N6916-0 N5...
# 1    N20036-0 N23513-1 N32536-0 N46976-0 N35216-0 N...
# 2    N36779-0 N62365-0 N58098-0 N5472-0 N13408-0 N5...
# 3    N6950-0 N60215-0 N6074-0 N11930-0 N6916-0 N248...
# 4    N5940-1 N23513-0 N49285-0 N23355-0 N19990-0 N3...
# 5    N29862-0 N48740-0 N11390-0 N5472-0 N53572-0 N2...
# 6    N42767-1 N30290-0 N36779-0 N20036-0 N32536-0 N...
# 7    N53687-0 N31289-0 N37458-0 N8455-0 N56211-0 N5...
# 8                  N45612-0 N60939-1 N33397-0 N19685-0
# 9    N29091-0 N60762-0 N29862-0 N512-0 N48740-0 N60...
# Name: 4, dtype: object
# 100%|██████████| 73152/73152 [00:42<00:00, 1730.05it/s]
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['sports']
# ['news']
# ['sports', 'news']
# ['weather', 'news']
# ['finance']
# ['sports', 'foodanddrink']
# ['health', 'music']
# ['news', 'tv']
# ['autos', 'foodanddrink', 'lifestyle', 'tv']
# ['sports', 'news']
# ['sports']
# ['foodanddrink', 'movies', 'tv', 'video']
# ['finance', 'foodanddrink', 'lifestyle']
# ['news', 'lifestyle']
# ['foodanddrink', 'travel']
# ['entertainment', 'foodanddrink']
# ['movies', 'news']
# ['entertainment', 'foodanddrink']
# ['sports']
# ['lifestyle']
# ['sports', 'news']
# ['sports', 'finance']
# ['news', 'video']
# ['weather', 'news']
# ['news', 'lifestyle']
# ['entertainment', 'tv']
# ['health', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'entertainment', 'foodanddrink', 'lifestyle']
# ['sports', 'lifestyle']
# ['autos', 'entertainment', 'travel']
# ['sports', 'entertainment']
# ['finance', 'news']
# ['sports', 'movies', 'news', 'tv']
# ['sports', 'finance']
# ['sports', 'music']
# ['finance', 'movies', 'lifestyle', 'travel']
# ['movies', 'foodanddrink', 'lifestyle', 'sports']
# ['news', 'music', 'lifestyle']
# ['news', 'lifestyle']
# ['health', 'news', 'lifestyle']
# ['autos', 'news']
# ['news']
# ['sports', 'finance', 'news']
# ['news']
# ['sports', 'finance']
# ['sports', 'foodanddrink']
# ['health', 'lifestyle']
# ['entertainment', 'foodanddrink']
# ['sports', 'foodanddrink']
# ['sports', 'news']
# ['sports', 'entertainment', 'movies']
# ['sports', 'lifestyle']
# ['news']
# ['autos', 'sports', 'entertainment']
# ['sports', 'news', 'travel']
# ['weather', 'lifestyle']
# ['health', 'sports', 'news']
# ['news', 'video']
# ['movies', 'news', 'lifestyle']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['sports', 'lifestyle']
# ['foodanddrink', 'autos', 'entertainment', 'music', 'lifestyle', 'health', 'sports', 'news']
# ['finance', 'news']
# ['foodanddrink', 'news']
# ['finance', 'lifestyle']
# ['sports', 'lifestyle']
# ['lifestyle']
# ['entertainment', 'tv', 'video']
# ['sports', 'music', 'lifestyle']
# ['sports', 'news']
# ['sports', 'news']
# ['sports']
# ['movies', 'lifestyle', 'video']
# ['health', 'video']
# ['news', 'lifestyle']
# ['weather', 'movies']
# ['finance', 'news']
# ['health', 'lifestyle']
# ['sports', 'tv']
# ['news']
# ['movies']
# ['movies', 'tv']
# ['sports', 'news']
# ['autos']
# ['movies', 'video']
# ['tv']
# ['sports', 'finance', 'lifestyle']
# ['sports', 'movies']
# ['foodanddrink', 'video']
# ['sports']
# ['news', 'lifestyle']
# ['foodanddrink', 'news']
# ['foodanddrink', 'news']
# ['autos', 'sports']
# ['lifestyle', 'tv']
# ['movies', 'news', 'lifestyle']
# ['sports', 'finance', 'video', 'weather', 'news']
# ['finance']
# ['sports', 'news']
# ['health', 'lifestyle', 'tv']
# ['movies']
# ['movies', 'foodanddrink']
# ['music', 'news']
# ['foodanddrink', 'tv']
# ['autos', 'news', 'lifestyle']
# ['autos', 'video']
# ['entertainment', 'lifestyle', 'tv']
# ['sports']
# ['weather', 'music', 'sports']
# ['travel', 'video']
# ['news', 'lifestyle']
# ['autos', 'entertainment', 'lifestyle', 'health', 'weather', 'news']
# ['sports', 'travel']
# ['autos', 'entertainment', 'travel']
# ['sports']
# ['sports', 'lifestyle']
# ['sports', 'tv']
# ['entertainment', 'finance']
# ['sports', 'news']
# ['tv']
# ['sports', 'entertainment', 'music']
# ['news', 'lifestyle']
# ['autos', 'news', 'lifestyle']
# ['sports', 'foodanddrink', 'lifestyle']
# ['entertainment', 'news']
# ['news']
# ['news']
# ['music', 'lifestyle']
# ['entertainment', 'lifestyle', 'autos', 'news', 'travel']
# ['autos', 'sports']
# ['lifestyle']
# ['entertainment', 'movies', 'music', 'sports', 'news']
# ['sports', 'news']
# ['sports']
# ['weather', 'finance', 'movies']
# ['entertainment', 'news', 'lifestyle']
# ['movies', 'music', 'lifestyle', 'finance', 'autos', 'news']
# ['autos', 'news']
# ['lifestyle']
# ['sports', 'movies', 'lifestyle', 'finance', 'video', 'autos', 'news']
# ['sports', 'travel']
# ['finance', 'news']
# ['sports', 'lifestyle']
# ['entertainment', 'movies', 'music', 'health', 'sports']
# ['foodanddrink', 'lifestyle']
# ['lifestyle', 'tv']
# ['health', 'movies']
# ['lifestyle', 'news', 'travel']
# ['sports', 'foodanddrink']
# ['foodanddrink']
# ['sports', 'tv']
# ['sports', 'foodanddrink', 'lifestyle']
# ['news', 'lifestyle']
# ['entertainment', 'foodanddrink']
# ['health', 'lifestyle']
# ['movies', 'tv']
# ['autos', 'entertainment', 'news']
# ['news', 'video']
# ['entertainment', 'movies', 'lifestyle', 'health', 'video']
# ['weather', 'music', 'lifestyle', 'sports']
# ['news', 'lifestyle', 'tv']
# ['health', 'finance', 'foodanddrink']
# ['movies', 'foodanddrink', 'news', 'tv']
# ['sports', 'tv']
# ['lifestyle']
# ['sports', 'finance', 'news', 'lifestyle']
# ['sports', 'foodanddrink', 'lifestyle']
# ['sports', 'news', 'video']
# ['sports', 'entertainment', 'movies', 'news']
# ['news', 'music']
# ['news']
# ['sports', 'movies']
# ['health', 'finance', 'movies', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports']
# ['sports', 'foodanddrink']
# ['news']
# ['sports', 'weather', 'news']
# ['sports', 'news']
# ['health', 'travel']
# ['news']
# ['finance', 'news', 'travel']
# ['lifestyle', 'video']
# ['entertainment', 'lifestyle']
# ['news']
# ['lifestyle', 'travel']
# ['news', 'lifestyle']
# ['foodanddrink', 'entertainment', 'music', 'tv', 'sports']
# ['sports', 'tv']
# ['autos', 'lifestyle']
# ['finance', 'tv']
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['lifestyle', 'tv', 'video']
# ['health', 'foodanddrink', 'lifestyle']
# ['lifestyle', 'tv']
# ['sports']
# ['foodanddrink', 'lifestyle']
# ['sports', 'news']
# ['autos', 'news', 'music']
# ['sports', 'video']
# ['weather', 'finance', 'lifestyle']
# ['entertainment', 'news']
# ['autos', 'sports']
# ['foodanddrink', 'music', 'lifestyle', 'health', 'tv', 'news']
# ['sports', 'news']
# ['health', 'entertainment']
# ['sports', 'entertainment', 'news', 'lifestyle']
# ['news', 'video']
# ['travel', 'lifestyle']
# ['lifestyle', 'video']
# ['sports', 'lifestyle']
# ['sports', 'music']
# ['lifestyle']
# ['health', 'sports', 'news']
# ['news', 'video']
# ['weather', 'sports']
# ['sports']
# ['sports', 'news', 'tv']
# ['health']
# ['autos', 'sports', 'weather']
# ['travel', 'music', 'lifestyle']
# ['finance', 'entertainment', 'lifestyle']
# ['sports', 'news']
# ['weather', 'news']
# ['health', 'entertainment', 'video']
# ['autos', 'sports', 'news']
# ['news', 'lifestyle']
# ['weather', 'music']
# ['sports', 'music', 'tv']
# ['sports', 'foodanddrink']
# ['sports', 'tv']
# ['health', 'news']
# ['sports', 'lifestyle']
# ['sports', 'news', 'tv']
# ['sports', 'tv']
# ['sports', 'movies', 'news']
# ['music', 'lifestyle']
# ['movies', 'news']
# ['sports', 'news']
# ['finance', 'lifestyle']
# ['sports', 'news', 'tv']
# ['news', 'tv']
# ['entertainment', 'foodanddrink', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports', 'foodanddrink']
# ['finance', 'news']
# ['travel', 'lifestyle']
# ['music', 'entertainment', 'news', 'lifestyle']
# ['news', 'tv']
# ['sports', 'news', 'travel']
# ['music', 'lifestyle']
# ['entertainment', 'news', 'lifestyle']
# ['sports', 'lifestyle']
# ['tv']
# ['sports', 'news', 'music']
# ['health', 'travel']
# ['entertainment', 'news']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['sports', 'movies', 'lifestyle']
# ['sports', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'tv']
# ['news', 'music']
# ['finance', 'foodanddrink']
# ['sports', 'finance', 'video']
# ['news']
# ['sports']
# ['sports', 'news', 'video']
# ['sports', 'news']
# ['sports', 'finance']
# ['sports', 'weather']
# ['sports', 'news', 'lifestyle']
# ['sports']
# ['news']
# ['news', 'music']
# ['lifestyle']
# ['sports', 'weather', 'news']
# ['news', 'lifestyle']
# ['autos', 'lifestyle']
# ['sports', 'movies']
# ['autos', 'news', 'travel', 'tv']
# ['lifestyle', 'tv']
# ['sports', 'news']
# ['entertainment', 'foodanddrink']
# ['news', 'tv']
# ['entertainment', 'travel', 'lifestyle']
# ['sports', 'news']
# ['foodanddrink', 'lifestyle']
# ['sports']
# ['sports', 'news']
# ['sports', 'tv']
# ['finance', 'lifestyle']
# ['sports', 'lifestyle']
# ['news', 'video']
# ['sports', 'movies', 'tv']
# ['sports', 'news']
# ['entertainment', 'lifestyle']
# ['sports', 'finance', 'news']
# ['sports', 'finance', 'lifestyle']
# ['sports', 'foodanddrink']
# ['autos', 'lifestyle']
# ['sports']
# ['entertainment', 'movies', 'lifestyle']
# ['finance', 'lifestyle']
# ['foodanddrink']
# ['sports', 'movies']
# ['finance', 'foodanddrink']
# ['autos', 'news', 'travel', 'sports']
# ['sports', 'foodanddrink']
# ['sports', 'foodanddrink']
# ['sports', 'lifestyle', 'video']
# ['news', 'video']
# ['news']
# ['sports', 'lifestyle']
# ['entertainment', 'news']
# ['health', 'foodanddrink']
# ['sports', 'video']
# ['autos', 'news']
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['sports', 'movies']
# ['tv']
# ['sports', 'tv']
# ['sports', 'foodanddrink']
# ['lifestyle', 'tv']
# ['foodanddrink', 'entertainment', 'movies', 'sports', 'news']
# ['sports', 'movies']
# ['sports', 'news']
# ['foodanddrink']
# ['sports', 'tv']
# ['sports', 'music']
# ['sports', 'finance', 'news', 'travel']
# ['movies', 'lifestyle']
# ['finance', 'lifestyle']
# ['weather', 'news']
# ['sports', 'news']
# ['finance', 'entertainment']
# ['weather', 'news', 'lifestyle']
# ['sports']
# ['sports']
# ['autos', 'entertainment', 'news', 'sports']
# ['autos', 'sports', 'video']
# ['health', 'sports', 'lifestyle']
# ['news']
# ['news', 'tv']
# ['entertainment', 'news', 'lifestyle']
# ['movies', 'news']
# ['music', 'news']
# ['autos', 'sports']
# ['sports', 'lifestyle', 'tv', 'autos', 'travel']
# ['sports', 'news']
# ['sports', 'video']
# ['sports', 'lifestyle']
# ['news', 'lifestyle']
# ['autos', 'travel', 'news', 'lifestyle']
# ['sports', 'finance', 'foodanddrink', 'travel']
# ['lifestyle']
# ['health', 'sports', 'news']
# ['health', 'tv']
# ['sports']
# ['sports', 'foodanddrink', 'entertainment', 'lifestyle', 'finance', 'autos']
# ['sports', 'news']
# ['foodanddrink', 'news']
# ['sports']
# ['sports', 'lifestyle']
# ['movies', 'lifestyle']
# ['lifestyle', 'finance', 'foodanddrink', 'travel']
# ['movies', 'lifestyle']
# ['music', 'lifestyle']
# ['sports', 'news']
# ['sports', 'video']
# ['autos', 'movies', 'news', 'lifestyle']
# ['sports', 'weather', 'news']
# ['sports', 'foodanddrink']
# ['weather', 'news', 'lifestyle']
# ['weather', 'lifestyle']
# ['sports']
# ['autos', 'news', 'video']
# ['sports', 'foodanddrink']
# ['foodanddrink', 'entertainment', 'lifestyle', 'health', 'finance', 'tv']
# ['sports', 'news', 'travel']
# ['sports']
# ['health', 'sports', 'lifestyle']
# ['autos', 'lifestyle']
# ['foodanddrink', 'news']
# ['entertainment']
# ['autos', 'entertainment', 'music', 'lifestyle']
# ['news', 'tv']
# ['autos', 'news']
# ['news']
# ['video']
# ['autos', 'news', 'lifestyle']
# ['sports']
# ['news']
# ['sports', 'news', 'music', 'tv']
# ['sports', 'movies']
# ['sports', 'weather']
# ['news']
# ['sports']
# ['sports', 'news']
# ['sports']
# ['health', 'music']
# ['sports', 'news']
# ['health', 'lifestyle']
# ['news']
# ['news', 'travel', 'tv']
# ['health', 'foodanddrink']
# ['sports', 'video']
# ['sports', 'finance']
# ['video']
# ['sports', 'news']
# ['sports', 'tv']
# ['news', 'tv']
# ['sports', 'foodanddrink', 'music', 'lifestyle']
# ['health', 'news', 'tv']
# ['sports', 'music']
# ['news']
# ['health', 'lifestyle', 'tv']
# ['foodanddrink', 'news']
# ['sports', 'music', 'tv']
# ['lifestyle', 'video']
# ['entertainment', 'movies']
# ['foodanddrink', 'lifestyle']
# ['sports', 'news']
# ['sports', 'news', 'lifestyle']
# ['lifestyle']
# ['movies', 'lifestyle']
# ['sports', 'lifestyle', 'tv']
# ['sports', 'news']
# ['news', 'tv']
# ['entertainment', 'news']
# ['health', 'finance']
# ['finance', 'music']
# ['lifestyle']
# ['news']
# ['sports']
# ['autos', 'tv']
# ['entertainment', 'movies', 'news', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['sports', 'foodanddrink']
# ['sports', 'foodanddrink']
# ['sports', 'news', 'lifestyle']
# ['news', 'video']
# ['sports', 'lifestyle']
# ['foodanddrink', 'movies', 'lifestyle', 'sports', 'news']
# ['sports', 'finance', 'news', 'lifestyle']
# ['autos', 'foodanddrink', 'sports']
# ['sports', 'travel']
# ['sports', 'entertainment', 'lifestyle']
# ['movies', 'news']
# ['sports', 'tv']
# ['sports', 'news', 'lifestyle', 'video']
# ['autos', 'sports']
# ['sports', 'tv']
# ['finance', 'news']
# ['sports', 'news']
# ['finance', 'news']
# ['news']
# ['autos', 'tv']
# ['news', 'lifestyle', 'tv']
# ['autos']
# ['sports', 'lifestyle']
# ['weather', 'entertainment', 'news']
# ['sports', 'tv']
# ['music', 'news']
# ['news', 'music', 'lifestyle']
# ['sports', 'music']
# ['sports', 'news']
# ['health', 'sports', 'travel']
# ['entertainment', 'news']
# ['entertainment', 'news']
# ['sports', 'movies', 'lifestyle']
# ['lifestyle', 'video']
# ['sports']
# ['sports', 'tv']
# ['health', 'autos', 'news']
# ['sports', 'tv']
# ['news']
# ['finance', 'news']
# ['sports', 'news']
# ['sports', 'news']
# ['news']
# ['sports']
# ['foodanddrink', 'lifestyle']
# ['entertainment', 'lifestyle', 'finance', 'sports', 'news']
# ['music', 'lifestyle']
# ['news', 'lifestyle', 'video']
# ['sports', 'news']
# ['health', 'news', 'lifestyle']
# ['sports', 'finance', 'news']
# ['news', 'travel']
# ['sports', 'foodanddrink', 'music', 'tv']
# ['health', 'weather', 'lifestyle']
# ['lifestyle', 'video']
# ['news', 'tv']
# ['foodanddrink', 'entertainment', 'music', 'health', 'video', 'sports', 'news', 'travel']
# ['sports', 'movies']
# ['foodanddrink']
# ['entertainment', 'news', 'lifestyle']
# ['weather', 'news', 'lifestyle']
# ['sports', 'weather']
# ['sports', 'finance', 'video']
# ['sports', 'lifestyle']
# ['news']
# ['sports']
# ['foodanddrink', 'lifestyle', 'video']
# ['sports', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['sports', 'news']
# ['sports', 'music']
# ['sports', 'finance', 'lifestyle']
# ['sports', 'video']
# ['movies', 'music', 'tv']
# ['sports', 'tv', 'video']
# ['sports']
# ['sports']
# ['movies', 'lifestyle']
# ['health', 'sports', 'news', 'travel']
# ['sports', 'lifestyle']
# ['sports', 'tv']
# ['movies', 'news', 'lifestyle', 'video']
# ['foodanddrink', 'lifestyle']
# ['sports']
# ['entertainment', 'news', 'tv']
# ['movies', 'foodanddrink', 'lifestyle']
# ['entertainment', 'news', 'lifestyle']
# ['news', 'tv']
# ['sports', 'news', 'video']
# ['sports', 'tv']
# ['music', 'lifestyle']
# ['sports', 'movies', 'music']
# ['foodanddrink', 'news']
# ['foodanddrink', 'movies']
# ['news', 'lifestyle']
# ['news', 'tv']
# ['sports']
# ['lifestyle']
# ['entertainment', 'music', 'video']
# ['lifestyle', 'health', 'finance', 'sports', 'news', 'travel']
# ['sports', 'music', 'lifestyle']
# ['finance', 'lifestyle']
# ['sports']
# ['autos', 'foodanddrink', 'news', 'travel']
# ['sports', 'entertainment', 'news']
# ['sports', 'entertainment']
# ['news', 'foodanddrink', 'music']
# ['autos', 'music', 'lifestyle']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['entertainment', 'lifestyle']
# ['sports', 'foodanddrink']
# ['sports', 'entertainment']
# ['sports', 'foodanddrink', 'lifestyle', 'finance', 'autos']
# ['health', 'autos', 'foodanddrink', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports', 'tv']
# ['sports']
# ['foodanddrink', 'entertainment', 'movies', 'lifestyle', 'health', 'finance', 'tv', 'news', 'travel']
# ['news', 'lifestyle']
# ['news']
# ['sports', 'foodanddrink', 'lifestyle', 'autos', 'travel']
# ['sports']
# ['sports', 'news', 'lifestyle', 'tv']
# ['finance', 'news']
# ['lifestyle', 'tv']
# ['entertainment', 'news']
# ['sports', 'news']
# ['finance', 'news']
# ['news', 'video']
# ['sports', 'movies']
# ['sports', 'news']
# ['foodanddrink', 'lifestyle']
# ['news', 'lifestyle']
# ['finance', 'news']
# ['sports', 'video']
# ['sports', 'lifestyle']
# ['sports', 'tv']
# ['sports', 'lifestyle', 'tv']
# ['lifestyle', 'tv']
# ['sports', 'foodanddrink']
# ['finance', 'travel', 'lifestyle']
# ['sports', 'tv']
# ['movies', 'news']
# ['sports', 'music', 'lifestyle']
# ['movies', 'lifestyle']
# ['news', 'lifestyle']
# ['lifestyle']
# ['autos', 'news']
# ['news', 'lifestyle']
# ['movies', 'news', 'lifestyle']
# ['news', 'lifestyle']
# ['health', 'sports']
# ['movies', 'news']
# ['health', 'sports']
# ['entertainment', 'tv']
# ['sports']
# ['health', 'travel']
# ['lifestyle']
# ['finance', 'lifestyle', 'tv']
# ['sports', 'news']
# ['lifestyle', 'tv']
# ['finance', 'movies', 'news']
# ['foodanddrink', 'news']
# ['health', 'sports', 'entertainment']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['news']
# ['sports', 'foodanddrink', 'video']
# ['foodanddrink', 'news']
# ['weather', 'sports']
# ['news', 'tv']
# ['foodanddrink', 'lifestyle']
# ['sports', 'music']
# ['sports', 'foodanddrink']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['weather', 'video']
# ['sports', 'tv']
# ['sports', 'news']
# ['weather', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['foodanddrink', 'news']
# ['news']
# ['entertainment', 'music', 'tv']
# ['autos', 'news']
# ['lifestyle', 'tv']
# ['sports', 'lifestyle']
# ['health', 'entertainment', 'news']
# ['sports', 'news']
# ['sports', 'foodanddrink']
# ['entertainment', 'travel', 'lifestyle']
# ['autos', 'sports']
# ['autos', 'weather', 'travel', 'sports']
# ['foodanddrink', 'lifestyle']
# ['foodanddrink', 'music', 'lifestyle', 'video', 'autos', 'news']
# ['health', 'foodanddrink', 'music', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['sports', 'lifestyle', 'tv']
# ['entertainment', 'music']
# ['sports', 'foodanddrink', 'music']
# ['sports', 'lifestyle']
# ['finance', 'news']
# ['entertainment', 'movies', 'lifestyle', 'health', 'finance', 'sports', 'news', 'travel']
# ['news', 'lifestyle']
# ['sports', 'foodanddrink', 'lifestyle']
# ['lifestyle']
# ['lifestyle']
# ['foodanddrink', 'lifestyle']
# ['sports', 'movies', 'music', 'lifestyle']
# ['lifestyle']
# ['autos', 'travel', 'sports']
# ['sports', 'lifestyle']
# ['sports', 'tv']
# ['news', 'lifestyle']
# ['news', 'lifestyle']
# ['music', 'lifestyle', 'tv']
# ['sports', 'movies']
# ['foodanddrink', 'lifestyle']
# ['sports']
# ['sports', 'movies']
# ['sports', 'video']
# ['tv']
# ['sports', 'finance', 'music']
# ['news', 'video']
# ['autos', 'foodanddrink', 'sports', 'tv']
# ['foodanddrink', 'travel']
# ['autos', 'weather', 'news']
# ['sports', 'movies', 'tv']
# ['news']
# ['autos', 'news', 'travel']
# ['sports', 'news']
# ['sports', 'tv']
# ['sports', 'foodanddrink']
# ['entertainment', 'tv']
# ['health', 'sports', 'entertainment', 'lifestyle']
# ['weather', 'foodanddrink', 'news']
# ['foodanddrink', 'news']
# ['entertainment', 'movies', 'news']
# ['sports', 'tv']
# ['autos', 'entertainment', 'foodanddrink', 'lifestyle']
# ['music', 'lifestyle']
# ['lifestyle', 'video']
# ['health', 'foodanddrink']
# ['news', 'lifestyle']
# ['health', 'news', 'lifestyle']
# ['entertainment', 'video']
# ['lifestyle']
# ['sports']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['news', 'lifestyle']
# ['sports']
# ['sports', 'finance']
# ['sports', 'lifestyle']
# ['music', 'tv']
# ['finance', 'tv']
# ['sports', 'entertainment']
# ['sports', 'lifestyle']
# ['music', 'lifestyle']
# ['lifestyle', 'tv']
# ['lifestyle', 'video']
# ['sports', 'lifestyle']
# ['sports']
# ['news']
# ['entertainment', 'news']
# ['health', 'entertainment', 'foodanddrink']
# ['weather', 'movies', 'sports']
# ['finance', 'entertainment', 'lifestyle']
# ['sports', 'movies', 'lifestyle']
# ['lifestyle', 'sports', 'travel', 'tv']
# ['health', 'lifestyle', 'tv']
# ['finance', 'lifestyle']
# ['music', 'lifestyle', 'health', 'finance', 'sports', 'news']
# ['sports', 'news']
# ['autos', 'sports']
# ['foodanddrink', 'lifestyle']
# ['sports', 'entertainment', 'movies', 'lifestyle']
# ['sports', 'news']
# ['sports', 'news']
# ['sports', 'foodanddrink', 'news']
# ['sports', 'news']
# ['autos', 'weather', 'news', 'travel']
# ['foodanddrink', 'finance', 'weather', 'news', 'travel']
# ['movies', 'news', 'lifestyle']
# ['sports']
# ['sports', 'movies']
# ['news', 'tv', 'video']
# ['sports', 'movies', 'travel', 'tv']
# ['health', 'sports']
# ['sports', 'tv']
# ['health']
# ['entertainment', 'foodanddrink']
# ['lifestyle']
# ['health', 'sports', 'entertainment']
# ['entertainment', 'news']
# ['lifestyle']
# ['foodanddrink', 'lifestyle', 'video', 'sports', 'news']
# ['lifestyle', 'travel']
# ['news']
# ['sports', 'foodanddrink']
# ['sports']
# ['movies', 'lifestyle']
# ['sports', 'movies']
# ['health', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'music']
# ['finance', 'news']
# ['health', 'finance', 'foodanddrink', 'travel']
# ['travel', 'news', 'lifestyle']
# ['foodanddrink', 'movies', 'tv']
# ['news', 'travel']
# ['finance', 'news']
# ['finance', 'travel', 'news', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['movies', 'foodanddrink', 'news']
# ['sports']
# ['sports', 'weather', 'news', 'video']
# ['news', 'lifestyle']
# ['movies', 'lifestyle']
# ['entertainment', 'tv']
# ['health', 'autos', 'news']
# ['news']
# ['health', 'entertainment']
# ['lifestyle']
# ['health', 'sports']
# ['foodanddrink', 'news']
# ['sports', 'movies']
# ['foodanddrink', 'movies', 'lifestyle', 'finance', 'sports']
# ['news', 'lifestyle']
# ['sports', 'news']
# ['foodanddrink', 'lifestyle']
# ['entertainment', 'tv']
# ['sports', 'entertainment']
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['movies', 'news']
# ['sports', 'movies', 'music']
# ['entertainment', 'lifestyle']
# ['news']
# ['movies', 'news']
# ['sports', 'lifestyle']
# ['health', 'sports', 'entertainment', 'lifestyle']
# ['weather', 'finance', 'foodanddrink']
# ['sports']
# ['travel']
# ['lifestyle']
# ['sports', 'news']
# ['news']
# ['sports', 'foodanddrink', 'tv']
# ['music', 'lifestyle']
# ['health', 'tv']
# ['sports', 'news']
# ['news', 'travel']
# ['foodanddrink', 'lifestyle', 'tv']
# ['health', 'autos', 'sports']
# ['sports', 'foodanddrink']
# ['health', 'finance']
# ['news', 'lifestyle']
# ['sports', 'news']
# ['news']
# ['autos', 'foodanddrink']
# ['sports', 'music', 'tv']
# ['news', 'lifestyle']
# ['weather', 'news']
# ['sports', 'finance']
# ['health', 'sports']
# ['news', 'lifestyle']
# ['lifestyle']
# ['music', 'news']
# ['sports']
# ['entertainment', 'lifestyle']
# ['news', 'tv']
# ['health', 'sports', 'lifestyle']
# ['sports', 'lifestyle']
# ['finance', 'foodanddrink', 'entertainment']
# ['sports', 'news']
# ['sports']
# ['music', 'tv']
# ['sports', 'news', 'lifestyle']
# ['sports']
# ['autos', 'sports', 'foodanddrink', 'news']
# ['news', 'video']
# ['foodanddrink']
# ['sports']
# ['sports', 'tv']
# ['sports', 'news']
# ['lifestyle', 'tv']
# ['music', 'news']
# ['sports']
# ['news', 'lifestyle']
# ['lifestyle', 'health', 'video', 'sports', 'travel']
# ['sports']
# ['travel']
# ['foodanddrink', 'news']
# ['sports', 'movies']
# ['sports', 'entertainment']
# ['weather', 'news']
# ['health', 'travel', 'lifestyle']
# ['health', 'lifestyle']
# ['sports', 'video']
# ['entertainment', 'news', 'video']
# ['sports', 'news']
# ['sports']
# ['news', 'lifestyle']
# ['health', 'news']
# ['travel', 'lifestyle']
# ['sports', 'tv']
# ['sports', 'news', 'travel']
# ['finance', 'video']
# ['health', 'video']
# ['weather', 'news']
# ['music', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['health', 'news', 'lifestyle']
# ['sports', 'foodanddrink', 'lifestyle', 'tv', 'autos', 'travel']
# ['sports', 'news']
# ['foodanddrink', 'lifestyle']
# ['weather', 'news']
# ['sports', 'movies', 'news', 'lifestyle']
# ['autos', 'weather']
# ['lifestyle', 'tv']
# ['health', 'news']
# ['foodanddrink', 'lifestyle']
# ['news', 'lifestyle']
# ['news', 'tv']
# ['lifestyle', 'video']
# ['news']
# ['sports', 'lifestyle']
# ['tv']
# ['finance', 'travel', 'lifestyle']
# ['autos', 'sports']
# ['weather', 'video']
# ['sports']
# ['sports', 'news']
# ['sports', 'finance', 'news']
# ['sports', 'finance']
# ['sports', 'lifestyle']
# ['music', 'news']
# ['sports', 'news']
# ['music', 'lifestyle']
# ['lifestyle', 'tv']
# ['tv', 'video']
# ['weather', 'news', 'lifestyle']
# ['sports', 'lifestyle']
# ['news', 'tv']
# ['foodanddrink', 'lifestyle']
# ['sports', 'foodanddrink', 'news']
# ['sports', 'tv']
# ['sports']
# ['sports']
# ['health']
# ['weather', 'news']
# ['sports', 'news']
# ['entertainment', 'news']
# ['sports']
# ['music', 'lifestyle']
# ['health', 'sports', 'news']
# ['foodanddrink', 'lifestyle']
# ['weather', 'travel']
# ['autos', 'lifestyle']
# ['sports', 'foodanddrink', 'news', 'tv']
# ['sports', 'movies']
# ['foodanddrink', 'news']
# ['health', 'finance']
# ['movies', 'lifestyle']
# ['health', 'sports', 'news']
# ['weather', 'news', 'music']
# ['sports', 'finance', 'music']
# ['autos', 'foodanddrink']
# ['sports', 'news']
# ['sports', 'news', 'lifestyle', 'tv']
# ['news', 'video']
# ['news', 'tv']
# ['entertainment', 'tv']
# ['foodanddrink', 'news']
# ['sports']
# ['finance', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports']
# ['health', 'sports', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'lifestyle']
# ['entertainment', 'lifestyle', 'video']
# ['sports', 'entertainment', 'movies', 'foodanddrink']
# ['sports', 'lifestyle']
# ['sports', 'finance', 'tv']
# ['health', 'foodanddrink', 'lifestyle']
# ['sports']
# ['sports', 'video']
# ['entertainment', 'music']
# ['travel', 'tv']
# ['health', 'lifestyle']
# ['health', 'music']
# ['entertainment', 'lifestyle']
# ['sports', 'news', 'music', 'lifestyle']
# ['news']
# ['news', 'lifestyle']
# ['movies', 'news']
# ['sports', 'entertainment', 'news']
# ['foodanddrink', 'news', 'lifestyle']
# ['news', 'video']
# ['foodanddrink', 'news']
# ['autos', 'news']
# ['health', 'tv']
# ['sports', 'news']
# ['music', 'video']
# ['sports']
# ['entertainment', 'movies']
# ['finance', 'news']
# ['autos']
# ['sports', 'news']
# ['sports', 'entertainment', 'news', 'tv']
# ['sports', 'news']
# ['news']
# ['music', 'news', 'lifestyle']
# ['autos', 'news']
# ['health', 'sports', 'news', 'autos']
# ['sports', 'news']
# ['sports', 'finance', 'news']
# ['sports', 'news']
# ['health', 'lifestyle']
# ['sports', 'news', 'video']
# ['sports', 'travel']
# ['lifestyle', 'travel', 'health']
# ['health', 'sports']
# ['foodanddrink', 'lifestyle']
# ['sports', 'video']
# ['weather', 'lifestyle']
# ['autos', 'sports']
# ['health', 'foodanddrink']
# ['travel', 'news', 'lifestyle']
# ['health', 'finance']
# ['health', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['sports', 'news', 'lifestyle', 'music']
# ['health', 'sports', 'lifestyle']
# ['sports']
# ['sports', 'entertainment', 'news']
# ['sports', 'music']
# ['entertainment', 'music', 'lifestyle']
# ['news', 'travel']
# ['news']
# ['sports', 'news']
# ['health', 'finance', 'lifestyle']
# ['entertainment', 'music']
# ['health', 'weather', 'tv']
# ['sports', 'finance', 'news']
# ['sports', 'news', 'lifestyle']
# ['sports']
# ['weather', 'entertainment', 'lifestyle']
# ['sports', 'lifestyle']
# ['news']
# ['health', 'sports', 'tv', 'video']
# ['weather', 'finance', 'news', 'lifestyle']
# ['lifestyle', 'tv']
# ['foodanddrink', 'lifestyle']
# ['sports']
# ['news', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['sports']
# ['sports', 'tv']
# ['sports', 'news']
# ['music', 'video']
# ['movies', 'music', 'lifestyle']
# ['music', 'news']
# ['sports', 'lifestyle']
# ['sports', 'music']
# ['sports', 'movies']
# ['sports', 'lifestyle']
# ['health', 'foodanddrink']
# ['sports']
# ['sports', 'entertainment', 'lifestyle']
# ['sports', 'video']
# ['sports', 'entertainment', 'news', 'lifestyle']
# ['sports']
# ['weather', 'news', 'travel', 'sports']
# ['foodanddrink', 'video']
# ['sports', 'lifestyle', 'tv']
# ['movies', 'tv']
# ['health', 'foodanddrink', 'news', 'lifestyle']
# ['sports', 'lifestyle']
# ['movies', 'lifestyle']
# ['sports', 'news']
# ['news', 'tv']
# ['entertainment', 'lifestyle']
# ['autos', 'entertainment']
# ['health', 'video']
# ['autos', 'video']
# ['sports']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['health', 'lifestyle']
# ['sports', 'news']
# ['finance', 'travel']
# ['weather', 'music']
# ['health', 'video']
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['sports', 'tv']
# ['health', 'weather', 'music']
# ['foodanddrink', 'music', 'lifestyle', 'sports', 'travel']
# ['sports']
# ['weather', 'news']
# ['autos', 'foodanddrink', 'lifestyle']
# ['news', 'video']
# ['news', 'lifestyle']
# ['health', 'news']
# ['foodanddrink', 'lifestyle']
# ['lifestyle', 'tv']
# ['autos', 'news']
# ['finance', 'tv']
# ['news', 'travel', 'tv']
# ['entertainment', 'lifestyle']
# ['news', 'lifestyle']
# ['finance', 'music', 'lifestyle']
# ['sports', 'lifestyle']
# ['health', 'sports', 'finance', 'news']
# ['entertainment', 'movies', 'lifestyle']
# ['news']
# ['sports', 'movies']
# ['foodanddrink', 'tv']
# ['sports', 'entertainment']
# ['finance', 'news', 'tv']
# ['lifestyle']
# ['finance', 'news']
# ['news']
# ['sports', 'news']
# ['sports', 'news', 'video']
# ['finance', 'lifestyle']
# ['sports']
# ['health', 'entertainment', 'news', 'lifestyle']
# ['entertainment', 'lifestyle', 'tv', 'weather', 'news', 'travel']
# ['health', 'lifestyle']
# ['sports', 'tv']
# ['lifestyle']
# ['autos', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'finance']
# ['foodanddrink', 'lifestyle']
# ['sports']
# ['sports']
# ['sports', 'news']
# ['autos', 'news']
# ['finance', 'music']
# ['health', 'lifestyle']
# ['weather', 'lifestyle']
# ['sports', 'foodanddrink']
# ['lifestyle']
# ['entertainment', 'foodanddrink', 'tv']
# ['sports']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['health', 'news']
# ['sports', 'music']
# ['lifestyle', 'tv']
# ['news', 'tv']
# ['sports', 'news']
# ['sports', 'news']
# ['autos', 'sports', 'news', 'lifestyle']
# ['sports']
# ['sports', 'news']
# ['sports']
# ['health', 'movies', 'news']
# ['autos', 'music']
# ['sports', 'video']
# ['sports', 'tv']
# ['foodanddrink', 'news']
# ['sports', 'lifestyle']
# ['entertainment', 'lifestyle', 'tv']
# ['health', 'entertainment', 'lifestyle']
# ['finance', 'foodanddrink', 'music']
# ['news']
# ['sports', 'weather', 'tv']
# ['sports']
# ['lifestyle', 'tv']
# ['news']
# ['autos', 'foodanddrink', 'news']
# ['sports', 'news']
# ['sports']
# ['movies', 'news']
# ['news']
# ['sports', 'news']
# ['health', 'lifestyle']
# ['sports', 'news']
# ['news', 'tv']
# ['sports', 'news', 'lifestyle']
# ['entertainment', 'lifestyle', 'tv']
# ['entertainment', 'news']
# ['news', 'lifestyle']
# ['sports', 'movies']
# ['sports', 'tv']
# ['news']
# ['sports', 'foodanddrink', 'news', 'tv']
# ['health', 'tv']
# ['sports', 'news', 'video']
# ['movies', 'news']
# ['news', 'video']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['autos', 'sports', 'news']
# ['finance', 'movies']
# ['sports', 'travel']
# ['sports', 'news']
# ['lifestyle']
# ['autos', 'sports']
# ['news', 'lifestyle']
# ['lifestyle', 'tv']
# ['sports', 'foodanddrink']
# ['movies', 'music', 'tv', 'sports', 'news', 'travel']
# ['sports', 'lifestyle']
# ['sports', 'news', 'tv']
# ['weather', 'lifestyle']
# ['sports', 'movies', 'news']
# ['news', 'tv']
# ['sports', 'news']
# ['entertainment', 'lifestyle', 'tv']
# ['foodanddrink', 'news']
# ['foodanddrink', 'lifestyle']
# ['entertainment', 'foodanddrink']
# ['movies', 'news']
# ['sports', 'news']
# ['news', 'lifestyle', 'video']
# ['news', 'tv']
# ['foodanddrink', 'lifestyle']
# ['sports', 'music', 'lifestyle']
# ['sports', 'lifestyle', 'tv']
# ['sports', 'movies']
# ['autos', 'travel']
# ['sports', 'tv']
# ['sports', 'tv']
# ['lifestyle']
# ['sports']
# ['weather', 'foodanddrink']
# ['sports', 'finance', 'news']
# ['movies', 'news']
# ['lifestyle']
# ['sports', 'news']
# ['sports', 'news']
# ['lifestyle', 'tv']
# ['movies', 'news', 'travel']
# ['sports', 'finance', 'news']
# ['sports', 'music', 'tv']
# ['news', 'video']
# ['sports', 'news']
# ['foodanddrink']
# ['sports', 'lifestyle', 'tv']
# ['autos', 'news']
# ['sports', 'news', 'lifestyle']
# ['finance', 'travel']
# ['finance', 'music', 'entertainment']
# ['finance', 'news']
# ['sports', 'finance', 'news']
# ['movies', 'news']
# ['health', 'news']
# ['health', 'finance', 'foodanddrink', 'news']
# ['entertainment', 'lifestyle']
# ['health', 'news']
# ['sports', 'foodanddrink']
# ['foodanddrink', 'lifestyle']
# ['health', 'entertainment', 'news', 'lifestyle']
# ['foodanddrink', 'news', 'lifestyle']
# ['finance', 'news']
# ['lifestyle']
# ['sports', 'travel']
# ['movies', 'health', 'tv', 'video', 'news']
# ['entertainment', 'movies', 'music', 'tv']
# ['sports', 'video']
# ['lifestyle', 'travel']
# ['sports']
# ['weather', 'sports']
# ['finance', 'news']
# ['foodanddrink', 'movies', 'music', 'lifestyle', 'sports', 'news']
# ['autos', 'news']
# ['sports', 'tv']
# ['lifestyle', 'health', 'finance', 'tv', 'travel']
# ['lifestyle', 'tv']
# ['weather', 'lifestyle']
# ['sports', 'news']
# ['sports', 'news', 'lifestyle']
# ['lifestyle', 'tv']
# ['health', 'news']
# ['sports', 'travel']
# ['autos', 'news']
# ['foodanddrink', 'tv']
# ['health', 'finance', 'news']
# ['news', 'lifestyle']
# ['music', 'news']
# ['news', 'tv', 'video']
# ['foodanddrink', 'lifestyle', 'tv', 'video', 'sports', 'news']
# ['foodanddrink', 'travel']
# ['foodanddrink', 'lifestyle']
# ['entertainment', 'lifestyle']
# ['sports', 'movies']
# ['weather', 'news']
# ['sports', 'music', 'lifestyle']
# ['news']
# ['sports', 'news']
# ['sports', 'foodanddrink']
# ['autos', 'news', 'music']
# ['music', 'foodanddrink', 'news']
# ['entertainment', 'foodanddrink', 'tv']
# ['sports', 'finance', 'news']
# ['finance', 'news', 'lifestyle']
# ['sports', 'news']
# ['sports']
# ['sports', 'news', 'lifestyle']
# ['news']
# ['health', 'finance', 'music']
# ['sports', 'music']
# ['health', 'foodanddrink', 'lifestyle', 'travel']
# ['sports', 'finance']
# ['foodanddrink', 'entertainment', 'lifestyle', 'health', 'weather']
# ['autos', 'sports', 'lifestyle']
# ['sports', 'news']
# ['sports', 'news']
# ['sports', 'tv']
# ['sports', 'music', 'tv']
# ['foodanddrink', 'lifestyle']
# ['entertainment', 'foodanddrink', 'lifestyle']
# ['sports', 'news']
# ['sports', 'finance', 'news', 'video']
# ['movies', 'lifestyle']
# ['autos', 'news', 'sports']
# ['news', 'lifestyle']
# ['autos', 'foodanddrink', 'news', 'lifestyle']
# ['sports', 'news']
# ['sports', 'lifestyle', 'video', 'autos', 'news']
# ['autos', 'sports']
# ['sports', 'video']
# ['lifestyle', 'foodanddrink', 'travel']
# ['sports', 'news', 'travel']
# ['health', 'lifestyle']
# ['news']
# ['sports', 'news']
# ['foodanddrink', 'lifestyle']
# ['movies', 'news', 'travel']
# ['autos', 'finance', 'sports']
# ['health', 'news']
# ['sports', 'lifestyle']
# ['sports', 'lifestyle']
# ['health', 'news', 'lifestyle']
# ['health', 'lifestyle']
# ['news']
# ['sports', 'tv']
# ['foodanddrink']
# ['news']
# ['sports', 'news']
# ['entertainment', 'music', 'lifestyle']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['sports', 'news']
# ['foodanddrink', 'lifestyle']
# ['entertainment', 'news']
# ['health']
# ['health', 'news', 'lifestyle']
# ['sports']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['autos', 'lifestyle']
# ['sports', 'video']
# ['sports', 'tv']
# ['health', 'sports', 'music']
# ['foodanddrink']
# ['finance', 'tv']
# ['sports', 'music']
# ['news']
# ['foodanddrink', 'news', 'lifestyle']
# ['entertainment', 'lifestyle', 'finance', 'news', 'travel']
# ['music', 'lifestyle']
# ['sports', 'weather']
# ['sports', 'entertainment', 'lifestyle', 'tv']
# ['news']
# ['autos', 'sports']
# ['sports', 'tv']
# ['sports', 'tv']
# ['foodanddrink', 'news']
# ['foodanddrink', 'news']
# ['sports', 'foodanddrink', 'lifestyle']
# ['autos', 'news', 'video']
# ['sports', 'news']
# ['sports', 'news']
# ['sports', 'finance']
# ['news']
# ['movies', 'lifestyle']
# ['lifestyle', 'tv']
# ['autos', 'news']
# ['news']
# ['finance', 'news']
# ['sports', 'news']
# ['sports', 'finance']
# ['news', 'lifestyle']
# ['health', 'tv']
# ['sports']
# ['weather', 'news', 'lifestyle']
# ['lifestyle']
# ['entertainment', 'foodanddrink', 'news']
# ['sports', 'foodanddrink', 'news', 'travel']
# ['sports', 'news']
# ['finance', 'news']
# ['sports', 'travel']
# ['sports', 'news', 'lifestyle']
# ['news', 'music']
# ['news']
# ['news']
# ['sports']
# ['health', 'music', 'lifestyle']
# ['sports']
# ['sports', 'news']
# ['lifestyle']
# ['news', 'video']
# ['lifestyle']
# ['sports', 'foodanddrink']
# ['sports', 'finance']
# ['foodanddrink', 'entertainment', 'health', 'tv', 'news']
# ['sports', 'movies', 'music', 'tv']
# ['sports', 'music', 'video']
# ['sports', 'video']
# ['sports', 'tv']
# ['finance', 'news']
# ['travel', 'news', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['news', 'video']
# ['news', 'lifestyle']
# ['news']
# ['news']
# ['sports', 'tv']
# ['entertainment', 'news']
# ['sports', 'tv']
# ['sports', 'tv']
# ['autos']
# ['sports', 'news']
# ['lifestyle']
# ['sports', 'foodanddrink', 'movies', 'news']
# ['news', 'lifestyle', 'tv']
# ['news']
# ['lifestyle', 'travel']
# ['autos', 'lifestyle']
# ['finance', 'movies', 'news', 'travel']
# ['news', 'lifestyle']
# ['health', 'news', 'lifestyle']
# ['sports']
# ['sports', 'finance']
# ['sports']
# ['news']
# ['health', 'news']
# ['lifestyle']
# ['movies']
# ['movies', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['entertainment', 'movies', 'news', 'lifestyle']
# ['health', 'sports', 'entertainment', 'lifestyle']
# ['autos', 'sports']
# ['news']
# ['sports', 'lifestyle']
# ['health', 'sports', 'entertainment', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports', 'news', 'weather', 'music']
# ['sports', 'music']
# ['health', 'sports', 'foodanddrink', 'lifestyle']
# ['music', 'news']
# ['entertainment', 'lifestyle']
# ['sports', 'music']
# ['music', 'lifestyle', 'health', 'finance', 'autos', 'news', 'travel']
# ['sports', 'finance']
# ['music', 'news']
# ['finance', 'news']
# ['lifestyle', 'news', 'travel']
# ['news', 'travel']
# ['news', 'video']
# ['sports', 'news']
# ['autos', 'news']
# ['sports', 'entertainment']
# ['sports', 'music', 'tv']
# ['entertainment', 'foodanddrink']
# ['sports', 'news']
# ['sports', 'movies', 'news']
# ['news']
# ['news']
# ['entertainment', 'health', 'tv', 'sports', 'news']
# ['sports', 'lifestyle']
# ['autos', 'finance']
# ['sports', 'news', 'music', 'lifestyle']
# ['news', 'lifestyle']
# ['health', 'news']
# ['weather', 'news']
# ['health', 'sports', 'tv']
# ['sports', 'news']
# ['sports', 'news']
# ['autos', 'news', 'sports']
# ['sports', 'news', 'lifestyle', 'music']
# ['movies', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['health', 'news']
# ['news']
# ['tv', 'video']
# ['lifestyle']
# ['music', 'lifestyle', 'health', 'news', 'travel']
# ['finance', 'news']
# ['news', 'lifestyle']
# ['health', 'autos', 'movies']
# ['sports', 'foodanddrink']
# ['foodanddrink', 'travel']
# ['sports', 'lifestyle']
# ['sports']
# ['sports', 'news']
# ['sports', 'entertainment']
# ['sports', 'movies', 'news']
# ['sports']
# ['sports', 'news']
# ['sports', 'foodanddrink', 'news', 'travel']
# ['autos', 'news']
# ['finance', 'foodanddrink', 'news']
# ['entertainment', 'finance', 'tv']
# ['foodanddrink', 'news', 'tv']
# ['news']
# ['sports', 'lifestyle']
# ['music', 'lifestyle']
# ['movies', 'news']
# ['sports']
# ['movies', 'news']
# ['sports', 'music']
# ['sports', 'lifestyle']
# ['finance', 'news', 'lifestyle']
# ['news', 'lifestyle']
# ['autos', 'news']
# ['sports', 'entertainment', 'tv']
# ['finance', 'news', 'tv']
# ['music', 'tv']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['lifestyle']
# ['autos', 'entertainment']
# ['sports', 'finance']
# ['movies', 'finance', 'video', 'news', 'travel']
# ['autos', 'news', 'sports', 'video']
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['movies', 'lifestyle']
# ['sports']
# ['autos', 'music']
# ['movies', 'travel']
# ['autos', 'foodanddrink']
# ['sports', 'foodanddrink', 'lifestyle']
# ['foodanddrink', 'news']
# ['sports', 'news', 'tv']
# ['finance', 'news', 'video']
# ['lifestyle', 'tv', 'sports', 'news', 'travel']
# ['sports', 'finance', 'news', 'travel']
# ['sports', 'lifestyle']
# ['health', 'lifestyle']
# ['news', 'lifestyle', 'tv']
# ['sports']
# ['sports', 'lifestyle']
# ['sports', 'lifestyle']
# ['finance', 'lifestyle']
# ['health', 'lifestyle']
# ['sports', 'lifestyle']
# ['health', 'foodanddrink', 'lifestyle', 'video']
# ['finance', 'travel']
# ['news']
# ['sports', 'news']
# ['autos', 'video']
# ['movies', 'news']
# ['foodanddrink', 'tv']
# ['autos', 'sports']
# ['autos', 'finance', 'news', 'sports']
# ['news']
# ['entertainment', 'movies', 'health', 'finance', 'video', 'sports', 'news']
# ['weather', 'news']
# ['entertainment', 'news']
# ['autos', 'finance']
# ['music', 'news']
# ['sports', 'news']
# ['movies', 'foodanddrink', 'news', 'video']
# ['video']
# ['sports', 'news']
# ['finance', 'lifestyle']
# ['entertainment', 'news']
# ['sports']
# ['sports', 'lifestyle']
# ['sports', 'travel']
# ['sports', 'finance', 'foodanddrink', 'news']
# ['foodanddrink', 'autos', 'entertainment', 'movies', 'finance', 'weather', 'news']
# ['entertainment', 'movies', 'lifestyle', 'news', 'travel']
# ['sports', 'news']
# ['sports', 'music']
# ['sports', 'tv']
# ['sports', 'video']
# ['news', 'lifestyle']
# ['music', 'lifestyle']
# ['news']
# ['movies', 'news']
# ['music', 'lifestyle', 'finance', 'tv', 'video', 'autos']
# ['weather', 'sports']
# ['sports']
# ['autos', 'music', 'lifestyle', 'health', 'sports', 'news']
# ['sports']
# ['news', 'travel']
# ['finance', 'lifestyle']
# ['sports']
# ['sports', 'news', 'lifestyle']
# ['sports', 'news', 'tv']
# ['entertainment']
# ['sports', 'foodanddrink']
# ['health', 'travel', 'tv']
# ['foodanddrink', 'news']
# ['sports', 'music']
# ['entertainment', 'lifestyle']
# ['movies']
# ['news', 'lifestyle']
# ['sports', 'news']
# ['sports', 'finance']
# ['news', 'tv']
# ['autos', 'news']
# ['music', 'news', 'lifestyle']
# ['health', 'sports', 'news', 'tv']
# ['sports']
# ['news', 'lifestyle']
# ['news', 'lifestyle']
# ['finance', 'news']
# ['foodanddrink', 'music']
# ['sports', 'news', 'lifestyle']
# ['sports', 'foodanddrink']
# ['news', 'lifestyle']
# ['foodanddrink', 'tv']
# ['news']
# ['travel', 'lifestyle']
# ['sports', 'lifestyle']
# ['news', 'video']
# ['sports', 'finance']
# ['finance', 'news']
# ['movies', 'finance', 'foodanddrink', 'tv']
# ['music', 'travel']
# ['autos', 'news']
# ['news', 'lifestyle']
# ['sports']
# ['news', 'travel']
# ['sports', 'lifestyle']
# ['travel', 'video']
# ['lifestyle']
# ['sports', 'news']
# ['sports', 'news']
# ['sports', 'weather']
# ['sports', 'news']
# ['news']
# ['health', 'lifestyle']
# ['sports', 'news']
# ['sports', 'news']
# ['entertainment', 'tv']
# ['sports', 'tv']
# ['sports']
# ['sports', 'news']
# ['autos', 'lifestyle']
# ['health', 'news']
# ['finance', 'travel']
# ['health', 'tv']
# ['sports', 'news']
# ['sports', 'foodanddrink', 'lifestyle']
# ['news', 'video']
# ['autos']
# ['news', 'lifestyle']
# ['sports', 'entertainment', 'music']
# ['sports']
# ['foodanddrink', 'news', 'lifestyle', 'tv']
# ['sports', 'movies', 'video']
# ['sports', 'news']
# ['news', 'tv']
# ['sports', 'finance', 'news']
# ['sports', 'movies']
# ['lifestyle', 'video']
# ['foodanddrink', 'entertainment', 'health', 'sports', 'news']
# ['sports', 'news']
# ['sports', 'news', 'music', 'video']
# ['news', 'lifestyle']
# ['movies', 'news']
# ['autos', 'lifestyle']
# ['finance', 'news']
# ['health', 'finance', 'foodanddrink', 'lifestyle']
# ['lifestyle', 'tv']
# ['finance', 'lifestyle']
# ['movies', 'tv']
# ['sports', 'tv']
# ['autos', 'video']
# ['sports', 'finance']
# ['sports']
# ['foodanddrink', 'lifestyle']
# ['finance', 'lifestyle']
# ['lifestyle', 'health', 'finance', 'sports', 'news']
# ['health', 'sports', 'weather', 'lifestyle']
# ['news', 'lifestyle']
# ['foodanddrink', 'news']
# ['news', 'travel']
# ['finance', 'news']
# ['news']
# ['sports']
# ['sports', 'tv']
# ['sports', 'travel']
# ['sports', 'tv']
# ['entertainment', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports', 'tv']
# ['sports', 'movies']
# ['foodanddrink', 'travel']
# ['foodanddrink', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['sports']
# ['news', 'tv']
# ['entertainment', 'news']
# ['sports', 'foodanddrink', 'lifestyle']
# ['weather', 'foodanddrink']
# ['news']
# ['autos', 'entertainment']
# ['finance', 'news']
# ['foodanddrink', 'news']
# ['sports', 'movies']
# ['finance', 'news']
# ['news']
# ['finance', 'foodanddrink', 'lifestyle']
# ['foodanddrink', 'music']
# ['news', 'video']
# ['autos', 'news']
# ['weather', 'news', 'travel']
# ['sports', 'movies', 'news']
# ['lifestyle', 'travel']
# ['finance', 'foodanddrink', 'travel']
# ['foodanddrink', 'travel']
# ['news', 'lifestyle', 'tv']
# ['sports', 'news', 'lifestyle', 'tv']
# ['foodanddrink', 'tv']
# ['finance', 'foodanddrink']
# ['news']
# ['sports', 'foodanddrink', 'lifestyle']
# ['entertainment', 'news']
# ['lifestyle']
# ['news']
# ['news']
# ['music', 'tv']
# ['sports', 'foodanddrink']
# ['music', 'lifestyle']
# ['sports', 'music']
# ['health', 'news']
# ['health', 'foodanddrink', 'news', 'travel']
# ['sports', 'news']
# ['sports', 'finance']
# ['sports', 'finance', 'news', 'tv']
# ['news']
# ['news', 'video']
# ['news']
# ['health', 'news', 'lifestyle']
# ['sports']
# ['foodanddrink', 'lifestyle']
# ['sports', 'finance']
# ['finance', 'news', 'lifestyle']
# ['autos', 'news']
# ['sports', 'tv']
# ['weather', 'news']
# ['sports']
# ['news']
# ['sports', 'entertainment', 'movies', 'lifestyle', 'finance', 'tv', 'autos']
# ['sports', 'music', 'travel', 'tv']
# ['sports', 'lifestyle']
# ['health', 'lifestyle']
# ['autos', 'sports']
# ['finance', 'music']
# ['sports']
# ['news']
# ['sports', 'lifestyle']
# ['sports', 'lifestyle', 'tv']
# ['foodanddrink', 'lifestyle', 'tv', 'sports', 'news']
# ['sports']
# ['sports', 'lifestyle']
# ['lifestyle', 'autos', 'travel', 'tv']
# ['sports', 'video']
# ['sports', 'lifestyle']
# ['health', 'movies']
# ['health', 'lifestyle']
# ['news', 'lifestyle']
# ['health', 'movies', 'lifestyle']
# ['finance', 'news']
# ['sports', 'lifestyle']
# ['sports']
# ['music', 'entertainment', 'movies', 'news']
# ['sports', 'news']
# ['news', 'music']
# ['sports', 'news']
# ['lifestyle', 'tv']
# ['foodanddrink', 'lifestyle']
# ['sports', 'news', 'lifestyle', 'music']
# ['sports', 'lifestyle']
# ['health', 'autos', 'sports']
# ['movies', 'news']
# ['sports', 'news']
# ['news', 'tv']
# ['lifestyle', 'weather', 'finance', 'travel']
# ['entertainment', 'lifestyle']
# ['sports', 'entertainment']
# ['travel', 'news', 'lifestyle']
# ['sports', 'news', 'music']
# ['weather']
# ['sports', 'video']
# ['sports', 'news', 'tv']
# ['health', 'entertainment', 'music', 'travel']
# ['sports', 'news']
# ['entertainment', 'news']
# ['music', 'travel', 'video']
# ['foodanddrink', 'news']
# ['sports', 'finance']
# ['sports', 'entertainment']
# ['news']
# ['lifestyle']
# ['sports', 'lifestyle']
# ['news', 'video']
# ['entertainment', 'movies', 'music', 'lifestyle', 'health', 'tv', 'news', 'travel']
# ['foodanddrink', 'lifestyle']
# ['lifestyle', 'foodanddrink', 'movies', 'travel']
# ['news', 'music', 'lifestyle']
# ['sports', 'news', 'video']
# ['news', 'lifestyle']
# ['news', 'lifestyle']
# ['lifestyle']
# ['lifestyle', 'tv']
# ['news', 'lifestyle']
# ['news', 'lifestyle']
# ['lifestyle', 'video']
# ['news', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['sports', 'lifestyle']
# ['weather', 'lifestyle']
# ['autos', 'finance', 'news', 'sports']
# ['foodanddrink', 'lifestyle']
# ['sports', 'tv']
# ['sports', 'lifestyle']
# ['news']
# ['movies', 'music', 'tv', 'sports', 'travel']
# ['health', 'sports', 'foodanddrink']
# ['sports', 'movies', 'news', 'tv']
# ['foodanddrink', 'travel']
# ['autos', 'news', 'lifestyle']
# ['weather', 'finance', 'travel']
# ['foodanddrink', 'news', 'travel', 'video']
# ['foodanddrink', 'news']
# ['lifestyle', 'tv']
# ['news', 'video']
# ['sports', 'music', 'tv']
# ['sports', 'music']
# ['autos', 'lifestyle']
# ['sports', 'foodanddrink', 'news']
# ['sports', 'news']
# ['sports', 'foodanddrink']
# ['autos', 'foodanddrink', 'news']
# ['news', 'video']
# ['sports', 'tv']
# ['health', 'weather', 'lifestyle']
# ['sports', 'news']
# ['music', 'lifestyle']
# ['sports', 'foodanddrink', 'travel']
# ['autos', 'lifestyle']
# ['autos', 'news']
# ['sports', 'lifestyle']
# ['sports', 'foodanddrink', 'tv']
# ['foodanddrink', 'tv']
# ['sports', 'lifestyle']
# ['foodanddrink', 'news']
# ['weather', 'lifestyle', 'sports']
# ['foodanddrink']
# ['news', 'foodanddrink', 'music']
# ['sports', 'foodanddrink']
# ['sports', 'finance']
# ['news', 'lifestyle']
# ['autos', 'movies']
# ['lifestyle']
# ['movies', 'news', 'video']
# ['sports']
# ['foodanddrink', 'music', 'finance', 'sports', 'news']
# ['weather', 'news', 'music', 'video']
# ['news']
# ['finance', 'video']
# ['movies', 'news']
# ['lifestyle']
# ['foodanddrink', 'tv']
# ['news', 'tv']
# ['health', 'sports', 'lifestyle']
# ['news', 'tv']
# ['sports', 'foodanddrink', 'news', 'lifestyle']
# ['music', 'lifestyle']
# ['sports', 'movies']
# ['sports', 'news', 'lifestyle']
# ['sports', 'news']
# ['news']
# ['sports', 'foodanddrink', 'news', 'lifestyle']
# ['health', 'news']
# ['sports', 'tv']
# ['news']
# ['weather', 'tv']
# ['entertainment', 'lifestyle']
# ['sports', 'foodanddrink']
# ['lifestyle', 'music', 'travel']
# ['lifestyle']
# ['sports', 'news', 'video']
# ['sports', 'lifestyle']
# ['autos', 'tv']
# ['sports', 'movies']
# ['finance', 'tv']
# ['sports', 'news']
# ['entertainment', 'tv']
# ['sports']
# ['health', 'foodanddrink']
# ['finance', 'news']
# ['music', 'lifestyle']
# ['sports']
# ['autos', 'foodanddrink', 'music']
# ['sports', 'news']
# ['entertainment', 'movies', 'lifestyle', 'health', 'tv', 'weather', 'news']
# ['news', 'tv']
# ['sports', 'lifestyle', 'tv']
# ['sports', 'foodanddrink', 'news']
# ['sports', 'tv']
# ['health', 'sports', 'foodanddrink']
# ['news', 'video']
# ['news', 'video']
# ['sports', 'movies']
# ['sports', 'tv']
# ['autos', 'music', 'tv']
# ['foodanddrink', 'tv']
# ['finance', 'foodanddrink', 'news', 'lifestyle']
# ['sports', 'news', 'travel']
# ['health', 'finance', 'news']
# ['health', 'sports']
# ['news']
# ['news']
# ['foodanddrink', 'news']
# ['sports', 'news', 'lifestyle']
# ['news', 'lifestyle', 'tv']
# ['autos', 'movies', 'news']
# ['autos', 'travel']
# ['news', 'video']
# ['lifestyle']
# ['news']
# ['health', 'news', 'lifestyle']
# ['news']
# ['movies', 'news']
# ['sports', 'travel']
# ['music', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'news']
# ['foodanddrink', 'lifestyle', 'health', 'tv', 'news']
# ['sports', 'tv']
# ['lifestyle']
# ['news', 'tv']
# ['health', 'sports', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports']
# ['autos', 'entertainment', 'movies', 'lifestyle', 'tv', 'sports', 'news']
# ['entertainment', 'lifestyle']
# ['finance', 'news']
# ['sports', 'foodanddrink']
# ['entertainment', 'tv']
# ['news']
# ['movies', 'news', 'video']
# ['foodanddrink', 'video']
# ...
# ['lifestyle', 'tv']
# ['sports', 'lifestyle', 'video']
# ['sports', 'travel', 'video']
# ['news', 'lifestyle']
# ['sports', 'news']
# ['finance', 'news', 'lifestyle']
# ['foodanddrink', 'news']
# ['finance', 'foodanddrink']
# ['health', 'sports']
# ['finance', 'tv']
# ['sports', 'news']
# ['health', 'music', 'tv', 'video']
# ['lifestyle', 'video']
# ['news', 'music']
# ['video']
# ['finance', 'foodanddrink', 'video']
# ['health', 'autos']
# ['sports', 'news', 'lifestyle']
# ['sports', 'lifestyle']
# ['weather', 'news', 'sports']
# ['sports']
# ['finance', 'news']
# ['health', 'news']
# ['foodanddrink', 'lifestyle']
# ['movies', 'foodanddrink', 'news', 'lifestyle']
# ['sports', 'foodanddrink']
# ['finance', 'lifestyle']
# ['entertainment', 'tv']
# ['health', 'autos']
# ['foodanddrink', 'tv']
# ['news', 'lifestyle']
# ['sports', 'tv']
# ['sports']
# ['health', 'travel']
# ['entertainment', 'news']
# ['sports', 'tv']
# ['sports', 'lifestyle']
# ['autos', 'news']
# ['music', 'news', 'lifestyle']
# ['sports', 'news', 'video']
# ['health', 'lifestyle']
# ['sports', 'movies']
# ['sports']
# ['sports', 'news', 'lifestyle', 'tv']
# ['finance', 'news']
# ['movies', 'news']
# ['news', 'travel']
# ['sports', 'news']
# ['sports', 'news']
# ['autos', 'news']
# ['finance', 'tv']
# ['sports']
# ['health', 'lifestyle']
# ['sports', 'foodanddrink']
# ['foodanddrink', 'news', 'lifestyle']
# ['lifestyle', 'tv']
# ['sports', 'travel', 'video']
# ['news']
# ['health', 'entertainment']
# ['health', 'lifestyle']
# ['weather', 'lifestyle']
# ['sports']
# ['lifestyle', 'tv', 'video', 'sports', 'news']
# ['health', 'entertainment', 'tv']
# ['movies', 'news']
# ['sports', 'entertainment', 'news']
# ['health', 'lifestyle']
# ['news', 'video']
# ['finance', 'news']
# ['health']
# ['health', 'autos', 'news']
# ['foodanddrink', 'entertainment', 'lifestyle', 'health', 'sports', 'news']
# ['sports', 'foodanddrink']
# ['sports', 'news']
# ['music', 'lifestyle']
# ['music', 'lifestyle']
# ['lifestyle', 'tv']
# ['health', 'sports', 'news', 'travel']
# ['entertainment', 'lifestyle']
# ['sports', 'movies']
# ['autos', 'foodanddrink', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['entertainment', 'tv']
# ['weather', 'finance']
# ['sports', 'news']
# ['sports']
# ['health', 'tv']
# ['health', 'weather']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['sports', 'lifestyle']
# ['autos', 'lifestyle']
# ['sports', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['sports', 'video']
# ['health', 'entertainment', 'lifestyle', 'tv']
# ['sports', 'tv']
# ['health']
# ['entertainment', 'music']
# ['news']
# ['sports', 'lifestyle']
# ['lifestyle']
# ['news', 'lifestyle']
# ['news']
# ['sports', 'lifestyle']
# ['sports', 'video']
# ['travel', 'lifestyle']
# ['sports', 'news']
# ['weather', 'news']
# ['news']
# ['news', 'tv', 'video']
# ['sports']
# ['music', 'travel', 'tv']
# ['sports', 'news']
# ['sports', 'finance', 'news']
# ['autos']
# ['sports', 'news', 'tv']
# ['health', 'sports', 'finance']
# ['sports', 'news']
# ['sports', 'foodanddrink', 'news']
# ['lifestyle']
# ['autos', 'news', 'lifestyle']
# ['sports']
# ['sports', 'tv']
# ['sports', 'entertainment', 'lifestyle']
# ['music', 'news', 'lifestyle']
# ['sports']
# ['sports', 'foodanddrink']
# ['foodanddrink', 'music', 'lifestyle']
# ['sports', 'news']
# ['movies', 'lifestyle', 'tv']
# ['movies', 'news']
# ['lifestyle', 'tv']
# ['sports']
# ['news', 'lifestyle']
# ['health', 'finance', 'lifestyle', 'tv']
# ['sports', 'lifestyle']
# ['sports', 'tv']
# ['movies']
# ['sports', 'music']
# ['sports', 'news', 'lifestyle']
# ['entertainment', 'news']
# ['news']
# ['sports', 'news']
# ['finance', 'lifestyle']
# ['health', 'foodanddrink']
# ['sports', 'foodanddrink']
# ['health', 'sports', 'entertainment', 'news']
# ['weather', 'foodanddrink']
# ['foodanddrink', 'news']
# ['movies', 'lifestyle']
# ['news']
# ['entertainment', 'foodanddrink']
# ['sports', 'foodanddrink', 'movies', 'lifestyle']
# ['sports', 'finance']
# ['news', 'video']
# ['lifestyle', 'tv']
# ['sports', 'news']
# ['sports']
# ['weather', 'lifestyle']
# ['news', 'lifestyle']
# ['movies', 'weather', 'lifestyle', 'finance', 'sports', 'news']
# ['news', 'lifestyle']
# ['sports']
# ['news', 'lifestyle']
# ['sports', 'news']
# ['sports', 'news']
# ['news', 'music']
# ['entertainment', 'movies', 'lifestyle', 'tv']
# ['weather', 'lifestyle', 'tv']
# ['autos', 'foodanddrink', 'sports']
# ['sports', 'foodanddrink']
# ['news']
# ['news', 'tv']
# ['health', 'news']
# ['lifestyle']
# ['sports', 'news', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['health', 'sports', 'music', 'lifestyle']
# ['finance', 'news']
# ['news', 'lifestyle']
# ['health', 'sports', 'music', 'lifestyle']
# ['sports', 'travel']
# ['news']
# ['autos', 'news', 'lifestyle']
# ['finance', 'video']
# ['health', 'entertainment', 'lifestyle']
# ['finance', 'lifestyle']
# ['news']
# ['sports', 'news']
# ['sports', 'foodanddrink', 'news']
# ['health', 'foodanddrink', 'music']
# ['news', 'lifestyle']
# ['news']
# ['finance', 'lifestyle', 'tv']
# ['sports', 'foodanddrink', 'lifestyle']
# ['finance', 'news', 'lifestyle', 'video']
# ['health', 'lifestyle']
# ['sports', 'news']
# ['sports', 'finance', 'lifestyle']
# ['sports', 'movies']
# ['autos', 'sports']
# ['finance', 'news']
# ['foodanddrink', 'news']
# ['entertainment', 'foodanddrink', 'news', 'lifestyle']
# ['sports']
# ['travel', 'lifestyle']
# ['foodanddrink']
# ['news', 'lifestyle']
# ['movies', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports']
# ['sports', 'finance']
# ['sports', 'entertainment']
# ['lifestyle', 'video']
# ['sports', 'news', 'lifestyle']
# ['news']
# ['sports', 'entertainment', 'foodanddrink']
# ['sports', 'lifestyle']
# ['sports', 'entertainment', 'foodanddrink']
# ['finance', 'news']
# ['autos', 'entertainment', 'movies', 'sports']
# ['news']
# ['entertainment', 'lifestyle']
# ['foodanddrink', 'travel']
# ['sports']
# ['health', 'foodanddrink', 'news']
# ['health', 'sports']
# ['health', 'news']
# ['movies', 'news']
# ['sports', 'music', 'lifestyle']
# ['lifestyle']
# ['lifestyle', 'travel']
# ['health', 'sports', 'news', 'tv']
# ['sports', 'news']
# ['news', 'video']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['foodanddrink', 'video']
# ['sports', 'tv']
# ['sports']
# ['foodanddrink', 'news', 'lifestyle', 'tv']
# ['lifestyle']
# ['sports', 'tv']
# ['movies', 'travel']
# ['health', 'news']
# ['foodanddrink', 'news', 'lifestyle']
# ['entertainment', 'movies', 'lifestyle', 'tv']
# ['lifestyle', 'sports', 'travel']
# ['sports']
# ['news', 'lifestyle']
# ['news']
# ['lifestyle', 'finance', 'tv', 'sports', 'news']
# ['autos', 'sports']
# ['news', 'video']
# ['foodanddrink', 'lifestyle']
# ['sports', 'news']
# ['entertainment', 'foodanddrink', 'news']
# ['news', 'travel']
# ['lifestyle', 'tv']
# ['lifestyle']
# ['travel', 'lifestyle']
# ['weather', 'lifestyle']
# ['sports', 'lifestyle', 'tv']
# ['lifestyle', 'tv']
# ['sports', 'news', 'tv']
# ['sports', 'foodanddrink']
# ['autos', 'news']
# ['sports', 'video']
# ['health', 'finance', 'music']
# ['music', 'news']
# ['sports', 'foodanddrink']
# ['weather', 'news']
# ['movies', 'lifestyle']
# ['sports', 'foodanddrink']
# ['entertainment', 'travel']
# ['sports', 'video']
# ['sports', 'foodanddrink', 'news', 'lifestyle']
# ['sports', 'foodanddrink']
# ['health']
# ['lifestyle', 'entertainment', 'travel']
# ['news']
# ['foodanddrink', 'lifestyle']
# ['sports', 'news']
# ['health', 'news']
# ['foodanddrink', 'music']
# ['sports', 'lifestyle']
# ['sports', 'entertainment']
# ['news', 'music']
# ['health', 'music']
# ['sports', 'news', 'video']
# ['music', 'lifestyle', 'health', 'finance', 'tv', 'sports', 'travel']
# ['sports', 'news']
# ['sports', 'entertainment']
# ['entertainment', 'lifestyle', 'tv']
# ['health', 'foodanddrink']
# ['sports', 'entertainment', 'news']
# ['movies', 'tv']
# ['sports']
# ['sports', 'foodanddrink']
# ['finance', 'travel']
# ['sports', 'lifestyle']
# ['news', 'lifestyle']
# ['finance', 'news']
# ['weather', 'foodanddrink']
# ['autos', 'finance']
# ['sports']
# ['health', 'finance', 'news']
# ['sports', 'tv']
# ['health', 'lifestyle']
# ['news']
# ['sports', 'music', 'travel']
# ['entertainment', 'news']
# ['autos', 'news']
# ['weather', 'tv']
# ['autos', 'sports', 'news', 'lifestyle']
# ['sports', 'news']
# ['health', 'sports', 'news']
# ['sports', 'finance']
# ['health', 'foodanddrink', 'lifestyle']
# ['foodanddrink', 'travel']
# ['news']
# ['sports', 'news', 'lifestyle']
# ['news', 'tv']
# ['sports', 'tv']
# ['sports', 'news', 'tv']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['news', 'tv']
# ['autos', 'news']
# ['news', 'lifestyle']
# ['health', 'sports', 'lifestyle']
# ['news']
# ['sports', 'news', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['health', 'foodanddrink']
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['autos', 'news', 'sports', 'video']
# ['music', 'tv']
# ['sports', 'travel']
# ['foodanddrink']
# ['sports']
# ['sports', 'finance']
# ['sports', 'video']
# ['news']
# ['sports', 'tv']
# ['sports', 'lifestyle', 'tv']
# ['foodanddrink', 'music']
# ['health']
# ['entertainment', 'finance']
# ['foodanddrink', 'lifestyle']
# ['sports', 'news']
# ['sports', 'lifestyle', 'video']
# ['sports', 'movies']
# ['foodanddrink', 'movies']
# ['foodanddrink', 'lifestyle']
# ['entertainment', 'news', 'lifestyle']
# ['sports', 'news', 'music']
# ['news', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'news', 'music']
# ['sports', 'news', 'video']
# ['sports', 'news']
# ['foodanddrink', 'movies', 'tv', 'sports', 'news']
# ['autos', 'travel']
# ['news']
# ['tv', 'video']
# ['sports', 'news']
# ['finance', 'entertainment', 'lifestyle', 'video']
# ['foodanddrink', 'movies', 'lifestyle', 'health', 'finance', 'video', 'weather', 'news']
# ['sports', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['news', 'lifestyle']
# ['travel', 'news', 'lifestyle']
# ['lifestyle']
# ['sports', 'news']
# ['sports', 'video']
# ['sports', 'lifestyle']
# ['sports']
# ['health', 'foodanddrink']
# ['autos', 'foodanddrink']
# ['sports', 'foodanddrink', 'lifestyle']
# ['sports', 'movies']
# ['sports', 'foodanddrink']
# ['health', 'tv']
# ['weather', 'lifestyle']
# ['news', 'lifestyle']
# ['autos', 'video']
# ['foodanddrink', 'news']
# ['foodanddrink', 'lifestyle']
# ['sports', 'foodanddrink']
# ['sports', 'music']
# ['sports', 'weather']
# ['sports', 'entertainment']
# ['news']
# ['music', 'lifestyle']
# ['sports', 'lifestyle']
# ['news', 'travel']
# ['entertainment', 'news']
# ['news', 'tv']
# ['sports', 'lifestyle']
# ['lifestyle', 'sports', 'movies', 'travel']
# ['sports', 'tv']
# ['lifestyle', 'sports', 'news', 'travel']
# ['foodanddrink', 'music', 'finance', 'video', 'news']
# ['health', 'lifestyle']
# ['travel', 'video']
# ['sports', 'news']
# ['news', 'lifestyle']
# ['foodanddrink', 'news', 'lifestyle']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['sports', 'news']
# ['sports', 'news']
# ['health', 'sports', 'foodanddrink']
# ['sports', 'lifestyle']
# ['movies', 'news', 'travel']
# ['health', 'foodanddrink']
# ['finance', 'news', 'video']
# ['sports', 'foodanddrink', 'weather']
# ['lifestyle', 'travel']
# ['lifestyle', 'tv']
# ['entertainment', 'news']
# ['sports', 'music']
# ['health', 'autos']
# ['sports']
# ['autos', 'movies', 'sports', 'video']
# ['news', 'tv']
# ['sports', 'lifestyle', 'video']
# ['sports', 'lifestyle']
# ['finance', 'lifestyle', 'tv']
# ['sports', 'lifestyle']
# ['news']
# ['sports', 'lifestyle', 'tv', 'video']
# ['movies', 'lifestyle']
# ['entertainment', 'music', 'tv']
# ['sports', 'news', 'tv']
# ['news', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['health', 'autos', 'news']
# ['news', 'lifestyle']
# ['sports']
# ['sports', 'news']
# ['sports']
# ['sports', 'news']
# ['sports', 'video']
# ['sports', 'entertainment']
# ['foodanddrink', 'health', 'sports', 'news', 'travel']
# ['sports', 'movies']
# ['health', 'movies']
# ['health', 'entertainment', 'tv']
# ['lifestyle', 'news', 'travel']
# ['sports', 'news']
# ['travel', 'news', 'lifestyle']
# ['news', 'lifestyle']
# ['sports', 'news']
# ['sports']
# ['movies', 'news', 'lifestyle', 'tv']
# ['sports', 'news']
# ['entertainment', 'travel']
# ['health', 'news']
# ['sports', 'foodanddrink', 'lifestyle']
# ['autos', 'sports']
# ['finance', 'news', 'lifestyle']
# ['sports', 'news']
# ['health', 'sports']
# ['health', 'finance', 'news']
# ['sports', 'news']
# ['travel']
# ['sports', 'lifestyle']
# ['sports', 'lifestyle']
# ['news', 'travel']
# ['movies', 'health', 'finance', 'news', 'travel']
# ['lifestyle', 'tv']
# ['news', 'lifestyle']
# ['foodanddrink', 'lifestyle']
# ['sports', 'lifestyle']
# ['movies', 'tv']
# ['autos', 'entertainment', 'lifestyle', 'tv']
# ['sports', 'tv']
# ['weather', 'news', 'sports']
# ['finance', 'lifestyle']
# ['foodanddrink', 'movies', 'music', 'lifestyle', 'sports']
# ['sports', 'video']
# ['sports']
# ['sports', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['foodanddrink', 'travel']
# ['sports', 'foodanddrink', 'news']
# ['sports', 'news']
# ['weather', 'entertainment']
# ['sports', 'entertainment', 'lifestyle']
# ['foodanddrink', 'entertainment', 'lifestyle', 'video', 'autos', 'travel']
# ['sports', 'entertainment', 'foodanddrink', 'lifestyle']
# ['foodanddrink', 'travel']
# ['news']
# ['sports', 'news', 'lifestyle']
# ['news']
# ['sports', 'music']
# ['sports']
# ['finance', 'foodanddrink', 'lifestyle', 'tv']
# ['sports', 'news', 'tv']
# ['lifestyle', 'tv']
# ['news']
# ['sports', 'lifestyle']
# ['weather', 'music']
# ['foodanddrink', 'entertainment', 'lifestyle', 'finance', 'tv', 'sports']
# ['news', 'video']
# ['sports', 'movies']
# ['health', 'entertainment', 'music']
# ['sports']
# ['health', 'sports', 'foodanddrink', 'tv']
# ['lifestyle', 'tv']
# ['health', 'sports', 'movies', 'lifestyle']
# ['sports']
# ['finance', 'news']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['movies', 'tv']
# ['sports']
# ['sports', 'music']
# ['weather', 'sports']
# ['finance', 'lifestyle']
# ['sports', 'music']
# ['entertainment', 'tv']
# ['health', 'travel']
# ['sports', 'news']
# ['sports', 'news', 'tv']
# ['tv', 'video']
# ['news', 'travel']
# ['news']
# ['sports', 'music']
# ['sports', 'foodanddrink', 'news']
# ['entertainment', 'news', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['sports', 'news']
# ['health', 'sports', 'lifestyle', 'tv']
# ['entertainment', 'foodanddrink', 'lifestyle', 'tv']
# ['news']
# ['sports', 'news']
# ['sports', 'news']
# ['music', 'tv']
# ['finance', 'news']
# ['sports', 'news', 'lifestyle']
# ['news', 'travel']
# ['sports']
# ['news', 'lifestyle', 'tv']
# ['movies', 'lifestyle', 'health', 'video', 'news']
# ['movies', 'lifestyle']
# ['autos', 'video']
# ['sports', 'news']
# ['movies', 'news']
# ['travel', 'news', 'lifestyle']
# ['sports', 'news']
# ['health', 'movies', 'news']
# ['sports', 'foodanddrink', 'music']
# ['sports', 'lifestyle']
# ['foodanddrink', 'entertainment', 'tv', 'video', 'sports']
# ['lifestyle']
# ['sports', 'news']
# ['sports', 'foodanddrink', 'news']
# ['sports', 'lifestyle']
# ['sports']
# ['sports', 'lifestyle']
# ['sports', 'news']
# ['sports', 'lifestyle']
# ['autos', 'sports', 'music', 'video']
# ['sports', 'lifestyle']
# ['autos', 'lifestyle']
# ['foodanddrink', 'news']
# ['sports', 'travel']
# ['sports']
# ['entertainment', 'lifestyle']
# ['autos', 'finance']
# ['news', 'tv']
# ['news', 'lifestyle']
# ['sports', 'news', 'lifestyle']
# ['news']
# ['autos', 'sports']
# ['sports', 'lifestyle']
# ['sports', 'lifestyle']
# ['sports', 'foodanddrink']
# ['news', 'tv']
# ['news', 'lifestyle', 'tv']
# ['music', 'travel']
# ['health', 'lifestyle']
# ['foodanddrink']
# ['foodanddrink', 'lifestyle']
# ['news']
# ['sports', 'news']
# ['news']
# ['sports', 'news']
# ['news', 'video']
# ['sports', 'news', 'lifestyle']
# ['sports', 'news', 'travel']
# ['health']
# ['lifestyle', 'finance', 'music', 'travel']
# ['sports', 'news']
# ['sports', 'music']
# ['sports', 'news', 'tv']
# ['travel', 'video']
# ['sports', 'lifestyle']
# ['lifestyle', 'tv']
# ['movies', 'lifestyle']
# ['foodanddrink', 'lifestyle', 'tv']
# ['sports']
# ['sports', 'movies', 'news']
# ['sports', 'news']
# ['sports', 'news', 'lifestyle']
# ['finance', 'lifestyle']
# ['finance', 'music', 'lifestyle']
# ['health', 'news', 'music', 'travel']
# ['health', 'lifestyle']
# ['health', 'autos', 'music', 'lifestyle']
# ['health']
# ['health', 'lifestyle']
# ['entertainment', 'news', 'lifestyle']
# ['health', 'entertainment']
# ['autos', 'tv']
# ['sports', 'news']
# ['health', 'sports', 'finance', 'music']
# ['sports', 'foodanddrink']
# ['news', 'lifestyle']
# ['news', 'travel']
# ['entertainment', 'news']
# ['foodanddrink', 'music', 'lifestyle', 'tv', 'sports', 'news']
# ['lifestyle']
# ['weather', 'lifestyle', 'health', 'tv', 'video', 'sports', 'news']
# ['health', 'sports', 'foodanddrink']
# ['movies', 'news']
# ['sports']
# ['foodanddrink', 'news']
# ['sports', 'finance']
# ['news']
# ['sports', 'lifestyle']
# ['sports', 'finance', 'travel']
# ['autos', 'entertainment', 'movies', 'lifestyle', 'health', 'finance', 'sports', 'news']
# ['autos', 'finance']

# %% [markdown]
# ## 2. 频繁模式挖掘
#
# 使用apyori算法对频繁模式进行挖掘。

# %%
from apyori import apriori

frequent_itemsets = list(apriori(data_list, min_support=0.1))

for itemset in frequent_itemsets:
    print(itemset.items)
# Out:
# frozenset({'finance'})
# frozenset({'foodanddrink'})
# frozenset({'health'})
# frozenset({'lifestyle'})
# frozenset({'news'})
# frozenset({'sports'})
# frozenset({'tv'})
# frozenset({'news', 'lifestyle'})
# frozenset({'sports', 'lifestyle'})
# frozenset({'sports', 'news'})

# %% [markdown]
# ## 对频繁模式命名
#
# 上面挖掘出了10个频繁模式，分别命名如下：
# 经济，隐式，健康，新闻，运动，电视，健康新闻，体育健康，体育新闻

# %%
# 挖掘关联规则
association_rules = list(apriori(data_list, min_support=0.1, min_confidence=0.1))

# 打印出关联规则
# for rule in association_rules:
#     print(rule)

for i in association_rules:
    for j in i.ordered_statistics:
        x = j.items_base
        y = j.items_add
        x = ",".join([item for item in x])
        y = ",".join([item for item in y])
        if x != "":
            print(x + " -> " + y)
# Out:
# lifestyle -> news
# news -> lifestyle
# lifestyle -> sports
# sports -> lifestyle
# news -> sports
# sports -> news
